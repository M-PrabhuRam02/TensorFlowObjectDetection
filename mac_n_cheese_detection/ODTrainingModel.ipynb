# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import os
os.chdir("/content/drive/My Drive/capstone/")

# %%
# !pwd
# Out:
# /content/drive/My Drive/capstone

# %%
# !set PYTHONPATH=object-detection-macaroni/models;object-detection-macaroni/models/research;object-detection-macaroni/models/research/slim
# Out:
# /bin/bash: object-detection-macaroni/models/research: Is a directory
# /bin/bash: object-detection-macaroni/models/research/slim: Is a directory

# %%
# !echo %PYTHONPATH%
# Out:
# %PYTHONPATH%

# %%
os.chdir("/content/drive/My Drive/capstone/object-detection-macaroni/models/research")

# %%
#protoc compilation
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim/nets

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# reading manifest file 'object_detection.egg-info/SOURCES.txt'
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying object_detection/protos/anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/argmax_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_coder_pb2.py -> build/lib/object_detection/protos
# ...

# %%
os.chdir("/content/drive/My Drive/capstone/object-detection-macaroni/models/research/object_detection")

# %%
os.chdir("/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg")

# %%
# !ls
# Out:
# EGG-INFO  object_detection

# %%
#Copying slim directory to object_detection-0.1-py3.6.egg
from distutils.dir_util import copy_tree
fromDirectory = "/content/drive/My Drive/capstone/object-detection-macaroni/models/research/slim/"
toDirectory = "/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg"

copy_tree(fromDirectory, toDirectory)
# Out:
# ['/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/export_mobilenet.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/finetune_inception_resnet_v2_on_flowers.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/finetune_inception_v1_on_flowers.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/train_lenet_on_mnist.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/train_cifarnet_on_cifar10.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/finetune_resnet_v1_50_on_flowers.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/scripts/finetune_inception_v3_on_flowers.sh',
#  '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/nets/nasnet/nasnet_utils_test.py',
# ...

# %%
# !ls
# Out:
# BUILD				nets
# datasets			object_detection
# deployment			preprocessing
# download_and_convert_data.py	README.md
# EGG-INFO			scripts
# eval_image_classifier.py	setup.py
# export_inference_graph.py	slim_walkthrough.ipynb
# export_inference_graph_test.py	train_image_classifier.py
# __init__.py			WORKSPACE

# %%
os.chdir("/content/drive/My Drive/capstone/object-detection-macaroni/models/research/object_detection")

# %%
#begin training the model
# !python legacy/train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/ssd_mobilenet_v1_pets.config
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py:125: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use object_detection/model_main.py.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/legacy/trainer.py:266: create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.create_global_step
# ...
